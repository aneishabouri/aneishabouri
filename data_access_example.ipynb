# %%
# %load_ext autoreload
# %load_ext google.cloud.bigquery
# %autoreload 2
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# !pip install feast[gcp,redis]
# !pip install plotly
# Out:
# [autoreload of google.auth.jwt failed: Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/conda/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/conda/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/opt/conda/lib/python3.7/site-packages/google/auth/jwt.py", line 296, in <module>
#     google.auth.credentials.Signing, google.auth.credentials.CredentialsWithQuotaProject
# AttributeError: module 'google.auth' has no attribute 'credentials'
# ]
# Requirement already satisfied: feast[gcp,redis] in /opt/conda/lib/python3.7/site-packages (0.17.0)
# Requirement already satisfied: pydantic>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.8.2)
# Requirement already satisfied: dill==0.3.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (0.3.4)
# Requirement already satisfied: proto-plus<1.19.7 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.19.6)
# Requirement already satisfied: tenacity>=7.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (8.0.1)
# Requirement already satisfied: fastavro>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.4.7)
# Requirement already satisfied: colorama>=0.3.9 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (0.4.4)
# Requirement already satisfied: pandas>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.3.5)
# Requirement already satisfied: mmh3 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (3.0.0)
# Requirement already satisfied: pandavro==1.5.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.5.2)
# Requirement already satisfied: pyarrow>=4.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (6.0.1)
# Requirement already satisfied: protobuf>=3.10 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (3.19.1)
# Requirement already satisfied: uvicorn[standard]>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (0.16.0)
# Requirement already satisfied: Jinja2>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (2.11.3)
# Requirement already satisfied: googleapis-common-protos==1.52.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.52.0)
# Requirement already satisfied: tqdm==4.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (4.62.3)
# Requirement already satisfied: tensorflow-metadata<2.0.0,>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.5.0)
# Requirement already satisfied: fastapi>=0.68.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (0.71.0)
# Requirement already satisfied: grpcio>=1.34.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.43.0)
# Requirement already satisfied: google-api-core>=1.23.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.31.5)
# Requirement already satisfied: Click==7.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (7.1.2)
# Requirement already satisfied: grpcio-reflection>=1.34.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.43.0)
# Requirement already satisfied: PyYAML>=5.4.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (6.0)
# Requirement already satisfied: toml==0.10.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (0.10.2)
# Requirement already satisfied: tabulate==0.8.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (0.8.9)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (4.3.1)
# Requirement already satisfied: redis-py-cluster==2.1.2 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (2.1.2)
# Requirement already satisfied: hiredis>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (2.0.0)
# Requirement already satisfied: google-cloud-datastore>=2.1.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (2.4.0)
# Requirement already satisfied: google-cloud-storage<1.41,>=1.34.* in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.40.0)
# Requirement already satisfied: google-cloud-bigquery>=2.28.1 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (2.31.0)
# Requirement already satisfied: google-cloud-core<2.0.0,>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (1.7.2)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from feast[gcp,redis]) (2.10.1)
# Requirement already satisfied: numpy>=1.7.0 in /opt/conda/lib/python3.7/site-packages (from pandavro==1.5.*->feast[gcp,redis]) (1.19.5)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.7/site-packages (from pandavro==1.5.*->feast[gcp,redis]) (1.16.0)
# Requirement already satisfied: redis<4.0.0,>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from redis-py-cluster==2.1.2->feast[gcp,redis]) (3.5.3)
# Requirement already satisfied: starlette==0.17.1 in /opt/conda/lib/python3.7/site-packages (from fastapi>=0.68.0->feast[gcp,redis]) (0.17.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from starlette==0.17.1->fastapi>=0.68.0->feast[gcp,redis]) (4.0.1)
# Requirement already satisfied: anyio<4,>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from starlette==0.17.1->fastapi>=0.68.0->feast[gcp,redis]) (3.4.0)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core>=1.23.0->feast[gcp,redis]) (59.6.0)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.7/site-packages (from google-api-core>=1.23.0->feast[gcp,redis]) (2021.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core>=1.23.0->feast[gcp,redis]) (2.26.0)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.7/site-packages (from google-api-core>=1.23.0->feast[gcp,redis]) (21.3)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core>=1.23.0->feast[gcp,redis]) (1.35.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery>=2.28.1->feast[gcp,redis]) (2.8.2)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery>=2.28.1->feast[gcp,redis]) (1.3.3)
# Requirement already satisfied: libcst>=0.2.5 in /opt/conda/lib/python3.7/site-packages (from google-cloud-bigquery-storage>=2.0.0->feast[gcp,redis]) (0.3.23)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from Jinja2>=2.0.0->feast[gcp,redis]) (1.1.1)
# Requirement already satisfied: absl-py<0.13,>=0.9 in /opt/conda/lib/python3.7/site-packages (from tensorflow-metadata<2.0.0,>=1.0.0->feast[gcp,redis]) (0.12.0)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (0.12.0)
# Requirement already satisfied: asgiref>=3.4.0 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (3.4.1)
# Requirement already satisfied: httptools<0.4.0,>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (0.3.0)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (0.19.2)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (0.16.0)
# Requirement already satisfied: watchgod>=0.6 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (0.7)
# Requirement already satisfied: websockets>=10.0 in /opt/conda/lib/python3.7/site-packages (from uvicorn[standard]>=0.14.0->feast[gcp,redis]) (10.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema->feast[gcp,redis]) (21.2.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from jsonschema->feast[gcp,redis]) (4.9.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema->feast[gcp,redis]) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema->feast[gcp,redis]) (0.18.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core>=1.23.0->feast[gcp,redis]) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core>=1.23.0->feast[gcp,redis]) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core>=1.23.0->feast[gcp,redis]) (4.8)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.7/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery>=2.28.1->feast[gcp,redis]) (1.1.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/conda/lib/python3.7/site-packages (from importlib-resources>=1.4.0->jsonschema->feast[gcp,redis]) (3.6.0)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from libcst>=0.2.5->google-cloud-bigquery-storage>=2.0.0->feast[gcp,redis]) (0.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging>=14.3->google-api-core>=1.23.0->feast[gcp,redis]) (3.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core>=1.23.0->feast[gcp,redis]) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core>=1.23.0->feast[gcp,redis]) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core>=1.23.0->feast[gcp,redis]) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core>=1.23.0->feast[gcp,redis]) (2021.10.8)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.7/site-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi>=0.68.0->feast[gcp,redis]) (1.2.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from google-crc32c<2.0dev,>=1.0->google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery>=2.28.1->feast[gcp,redis]) (1.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core>=1.23.0->feast[gcp,redis]) (0.4.8)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.7/site-packages (from typing-inspect>=0.4.0->libcst>=0.2.5->google-cloud-bigquery-storage>=2.0.0->feast[gcp,redis]) (0.4.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->google-crc32c<2.0dev,>=1.0->google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery>=2.28.1->feast[gcp,redis]) (2.21)
# Collecting plotly
#   Downloading plotly-5.5.0-py2.py3-none-any.whl (26.5 MB)
#      |████████████████████████████████| 26.5 MB 6.2 MB/s
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from plotly) (1.16.0)
# Installing collected packages: plotly
# Successfully installed plotly-5.5.0

# %%
import logging

from feast import FeatureStore

import plotly.express as px
import tensorflow as tf
from google.cloud.bigquery.job import QueryJobConfig
from feast.infra.offline_stores.bigquery import BigQueryOfflineStoreConfig
from feast import RepoConfig

logging.getLogger().setLevel(logging.INFO)
tf.get_logger().setLevel('INFO')

# %%
GOOGLE_CLOUD_PROJECT = "ueat-data-science-staging"
GOOGLE_CLOUD_REGION = "northamerica-northeast1"

# %% [markdown]
# Configure the access for Feast

# %%
FEAST_REGISTRY = "gs://ueat-feast-staging/data/registry.db"
FEAST_OFFLINE_DATASET =  "ueat_ai"


FEAST_OFFLINE_STORE_CONFIG = BigQueryOfflineStoreConfig(dataset=FEAST_OFFLINE_DATASET,
                                                        project_id=GOOGLE_CLOUD_PROJECT,
                                                        location=GOOGLE_CLOUD_REGION)

FEAST_REPO_CONFIG = RepoConfig(provider="gcp",
                               registry=FEAST_REGISTRY,
                               project="feature_repo",
                               offline_store=FEAST_OFFLINE_STORE_CONFIG)

DATASET_WITH_FEATURE = "ueat-data-science-staging.ueat_ai.asana_test_dataset"

store = FeatureStore(config=FEAST_REPO_CONFIG)

# %%
# Use this command for executing on a smaller dataset
#bigquery_entity_table = "ueat-data-science-staging.ueat_ai.RECSYS_ENTITIES_WITH_SPLIT_TEST"

bigquery_entity_table = "ueat-data-science-staging.ueat_ai.RECSYS_ENTITIES_WITH_SPLIT"

raw_data_query = f"""
SELECT
     RANK
    ,ORDER_ITEM_ID
    ,ORDER_ID
    ,ITEM_ID
    ,ROOT_ITEM_ID
    ,GLOBAL_USER_PROFILE_ID
    ,SERVICE_ID
    ,RESTAURANT_PROFILE_ID
    ,HEADQUARTER_PROFILE_ID
    ,QUANTITY
    ,CREATED_AT as event_timestamp
    ,CREATED_AT_LOCAL
    ,PROCESSED_DATE
    ,PROCESSED_DATE_LOCAL
    ,READY_DATE_LOCAL
    ,NEXT_ITEM_ID
    ,NEXT_ROOT_ITEM_ID
    ,SPLIT_STRATEGY_GLOBAL
    ,SPLIT_STRATEGY_HEADQUARTER
    ,SPLIT_STRATEGY_HYBRID
FROM `{bigquery_entity_table}` re
"""

# %% [markdown]
# Create the joined dataset with features on BigQuery

# %%
features = [
    "feature_menu_services:TYPE_DELIVERY",
    "feature_menu_services:TYPE_TAKEOUT",
    "feature_menu_services:TYPE_IN_RESTAURANT",
    "feature_menu_services:TYPE_OTHER",
    "feature_restaurants:POSTAL_CODE",
    "feature_restaurants:PROVINCE",
    "feature_items:DISPLAY_NAME",
    "feature_items:IS_ITEM",
    "feature_items:IS_VARIATION",
    "feature_items:IS_OPTION",
    "feature_items:IS_SUGGESTION"
]

retrieval_job = store.get_historical_features(
            entity_df=raw_data_query,
            features=features
)

job_config = QueryJobConfig(destination=DATASET_WITH_FEATURE, write_disposition="WRITE_TRUNCATE")

dataset_table = retrieval_job.to_bigquery(job_config=job_config)
# Out:
# Done writing to 'ueat-data-science-staging.ueat_ai.asana_test_dataset'.

# %% [markdown]
# Once this is done we can access the dataset directly from BigQuery
#
# We load  a sample (10 %) of the data in a pandas dataframe with %%bigquery

# %%
# %%bigquery sample_data
# SELECT
#     *
# FROM `ueat-data-science-staging.ueat_ai.asana_test_dataset` TABLESAMPLE SYSTEM (10 PERCENT)
# Out:
# Query complete after 0.01s: 100%|██████████| 2/2 [00:00<00:00, 1008.00query/s]
# Downloading: 100%|██████████| 3646375/3646375 [00:06<00:00, 576410.67rows/s]

# %%
sample_data.head(5)
# Out:
#    RANK  ORDER_ITEM_ID  ORDER_ID  ITEM_ID  ROOT_ITEM_ID  \
# 0    31       48112752  36004684    85280         85280
# 1    34       26078019  18428116    67036         67036
# 2    18       49537198  37036845   171280        171280
# 3    26       36640607  27265234   166683        166683
# 4    19       57338944  42770542   454880        454880
#
#    GLOBAL_USER_PROFILE_ID  SERVICE_ID  RESTAURANT_PROFILE_ID  \
# 0                  419306        4729                    682
# 1                  675294        4783                    689
# 2                 1706504       11606                   1509
# 3                  750531       11975                   1557
# 4                 1861068       90454                   5178
#
#    HEADQUARTER_PROFILE_ID  QUANTITY  ... TYPE_TAKEOUT TYPE_IN_RESTAURANT  \
# 0                     328         1  ...         True              False
# 1                     237         1  ...         True              False
# 2                     695         1  ...        False              False
# 3                     722         1  ...         True              False
# 4                    1774         1  ...         True              False
#
#   TYPE_OTHER POSTAL_CODE   PROVINCE    DISPLAY_NAME  IS_ITEM IS_VARIATION  \
# 0      False       08019  Catalunya      espárragos    False        False
# 1      False         G8Y     Québec  sauce tzatziki    False        False
# 2      False     J9T 1T7     Québec     poutine bbq    False        False
# 3      False     G6W 8H1     Québec  gâteau chômeur     True        False
# 4      False     R2V 4G4   Manitoba       cucumbers    False        False
#
#   IS_OPTION IS_SUGGESTION
# 0      True         False
# 1      True         False
# 2      True         False
# 3      True         False
# 4      True         False
#
# [5 rows x 31 columns]

# %% [markdown]
# The relevant features tables in BigQuery are:
#
#     1. FEATURE_MENU_SERVICES: Features about the type of service
#
#     2. FEATURE_RESTAURANTS: Features about the restaurant mainly geographic
#
#     3. formatted_feature_items: Formatted features items
